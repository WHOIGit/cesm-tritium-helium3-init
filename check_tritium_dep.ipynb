# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import netCDF4
from matplotlib import colors
# %matplotlib notebook

# %%
fp = netCDF4.Dataset('/home/ivan/Python/data/gx1v6.nc','r')
tlat = fp.variables['TLAT'][:]
tlon = fp.variables['TLONG'][:]
fp.close()
nlon, nlat = 320, 384
tritium_dep = np.loadtxt('dep.txt')
tritium_dep = tritium_dep.reshape((nlat,nlon))
tritium_dep.min(), tritium_dep.max()
# Out:
# (0.0, 145.81461531880512)

# %%
fig, ax = plt.subplots()
im = ax.imshow(tritium_dep,origin='lower',cmap=plt.cm.OrRd,norm=colors.LogNorm())
ax.set(title='[$^3$H] in precipitation')
cb = fig.colorbar(im,ax=ax)
cb.set_label('TU')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# fig, ax = plt.subplots()
# pm = ax.pcolormesh(tlon,tlat,tritium_dep,cmap=plt.cm.OrRd,norm=colors.LogNorm())
# ax.set(xlabel='longitude',ylabel='latitude',title='[$^3$H] in precipitation')
# cb = fig.colorbar(pm,ax=ax)
# cb.set_label('TU')
